# %% [markdown]
# # Analyse mgnify data

# %%
# %load_ext autoreload
# %autoreload 2

import mgnify_helper_functions as mhf

mgnify_data = mhf.MGnifyData(base_folder='data/mgnify_cache')

# %% [markdown]
# ### Study sizes analysis
# ---

# %%
study_sizes = mgnify_data.get_study_sample_sizes()

# %%
import json
import matplotlib.pyplot as plt

with open('data/study_sizes.json', "r") as file:
    checkpoint = json.load(file)
study_sizes = checkpoint["study_sizes"]
study_sizes = {k: v for k, v in study_sizes.items() if v is not None}
sizes = sorted(study_sizes.values(), reverse=True)

# plot long-tailedness of study sizes
plt.plot(range(len(sizes[1:])), sizes[1:])
plt.xlabel('Study index')
plt.ylabel('Number of samples')
plt.title('Study sizes')
plt.show()

# %% [markdown]
# <font color=green>

# %% [markdown]
# <font color="green"> We indeed observe that most datasets have a sample size smaller than 1000.</font>
#
# ---

# %%
study_sizes_tuple = [(k, v) for k, v in study_sizes.items()]
study_sizes_tuple.sort(key=lambda x: x[1], reverse=True)
study_sizes_tuple[:50]

# %% [markdown]
# ### Studies with GO summary analysis (To Be Done)

# %%
s = mhf.studies_with_desired_summaries()

# %%
print(s)
import json
with open('result.json', 'w') as fp:
    json.dump(s, fp)

from jsonapi_client import Session

# BASE_API = "https://www.ebi.ac.uk/metagenomics/api/latest/"
                                  

# download_path = "studies/MGYS00001980/downloads"
# with Session(BASE_API) as mgnify:
#     downloads = mgnify.get(download_path)
#     print(type(downloads.resources[0].description.label))
#     # print(float(downloads.resources[0].pipeline.id))
# Out:
# {'MGYS00006736': [], 'MGYS00006725': [], 'MGYS00001228': [], 'MGYS00006570': ['5.0'], 'MGYS00001980': ['4.0', '5.0']}

# %% [markdown]
# ### Difference between v4.0 and v5.0 for a dataset

# %%
import pandas as pd

MGYS00001980_v4 = pd.read_table("data/MGYS00001980(two_pipelines)/ERP103961_GO_abundances_v4.0.tsv", usecols=["GO", "description", "category"])
MGYS00001980_v5 = pd.read_table("data/MGYS00001980(two_pipelines)/ERP103961_GO_abundances_v5.0.tsv", usecols=["GO", "description", "category"])

print(len(set(MGYS00001980_v4["GO"])), "vs", len(set(MGYS00001980_v5["GO"])))

v4_descriptions = MGYS00001980_v4["description"]
v5_descriptions = MGYS00001980_v5["description"]
print("difference in descriptions")
print(set(v4_descriptions) - set(v5_descriptions), "\n of length", len(set(v4_descriptions) - set(v5_descriptions)))
print(set(v5_descriptions) - set(v4_descriptions), "\n of length", len(set(v5_descriptions) - set(v4_descriptions)))

v4_GO = MGYS00001980_v4["GO"]
v5_GO = MGYS00001980_v5["GO"]
print("difference in GO")
print(set(v4_GO) - set(v5_GO), "\n of length", len(set(v4_GO) - set(v5_GO)))
print(set(v5_GO) - set(v4_GO), "\n of length", len(set(v5_GO) - set(v4_GO)))
# Out:
# 3171 vs 2978
# difference in descriptions
# {'fusion of virus membrane with host plasma membrane', 'cell motility', 'plasminogen activation', 'protein kinase inhibitor activity', 'guanylate cyclase activator activity', '3-hydroxyanthranilate 3,4-dioxygenase activity', 'suppression by virus of host apoptotic process', 'electron transporter, transferring electrons within cytochrome b6/f complex of photosystem II activity', 'ribonucleoside-diphosphate reductase activity, thioredoxin disulfide as acceptor', 'transferase activity, transferring amino-acyl groups', 'calcium- and calmodulin-responsive adenylate cyclase activity', 'pyruvate, water dikinase activity', 'oxidoreductase activity, acting on the CH-NH2 group of donors, NAD or NADP as acceptor', 'propanediol dehydratase activity', 'cell morphogenesis involved in conjugation with cellular fusion', 'sodium:potassium-exchanging ATPase activity', 'nicotinate nucleotide biosynthetic process', 'toxin-antitoxin complex', 'host cell cytoplasm', 'toxin activity', '4-hydroxyphenylacetate transport', 'oxidoreductase activity, acting on the aldehyde or oxo group of donors, disulfide as acceptor', 'presynaptic active zone', 'myristoyl-[acyl-carrier-protein] hydrolase activity', 'retrograde vesicle-mediated transport, Golgi to ER', 'sperm chromatin condensation', 'pyruvate, phosphate dikinase activity', 'alkanesulfonate monooxygenase activity', 'bacterial-type flagellum basal body, distal rod, P ring', 'plastoquinol--plastocyanin reductase activity', 'oxidoreductase activity, acting on single donors with incorporation of molecular oxygen', 'transferase activity, transferring glycosyl groups', 'bicellular tight junction', 'oxidoreductase activity, acting on a sulfur group of donors, disulfide as acceptor', 'oxidoreductase activity, acting on the CH-NH2 group of donors, oxygen as acceptor', 'oxidoreductase activity, acting on paired donors, with incorporation or reduction of molecular oxygen', 'pyrimidine deoxyribonucleoside metabolic process', "exoribonuclease activity, producing 5'-phosphomonoesters", 'drug transmembrane transport', 'light-harvesting complex', 'high-affinity iron ion transmembrane transport', 'ecdysis, chitin-based cuticle', 'rRNA (adenine) methyltransferase activity', 'antibiotic transport', 'dormancy process', 'reciprocal meiotic recombination', 'maturation of SSU-rRNA from tricistronic rRNA transcript (SSU-rRNA, 5.8S rRNA, LSU-rRNA)', 'acireductone synthase activity', 'viral scaffold', 'vacuolar proton-transporting V-type ATPase, V1 domain', '3,4-dihydroxybenzoate catabolic process', 'electron transporter, transferring electrons within the cyclic electron transport pathway of photosynthesis activity', 'proton-transporting V-type ATPase, V1 domain', 'beta-amylase activity', 'condensed nuclear chromosome', 'response to biotic stimulus', 'oxidoreductase activity, acting on paired donors, with incorporation or reduction of molecular oxygen, reduced pteridine as one donor, and incorporation of one atom of oxygen', 'proteasome core complex, alpha-subunit complex', 'bacterial-type flagellum basal body, rod', 'chemokine binding', 'substrate-specific transmembrane transporter activity', 'protein deacetylation', 'phosphate ion transmembrane transporter activity', 'hydroxymethyl-, formyl- and related transferase activity', 'bacterial-type flagellum basal body, MS ring', 'bacterial-type flagellum basal body, distal rod, L ring', 'mating type determination', 'positive regulation of I-kappaB kinase/NF-kappaB signaling', 'propionate metabolic process, methylcitrate cycle', 'insulin receptor binding', 'regulation of translational initiation', 'transferase activity, transferring phosphorus-containing groups', 'ecdysteroid hormone receptor activity', 'DNA catabolic process, endonucleolytic', 'inflammatory response', '2-polyprenyl-6-methoxy-1,4-benzoquinone methyltransferase activity', 'binding', 'hydrolase activity, hydrolyzing N-glycosyl compounds', 'carbon-nitrogen ligase activity, with glutamine as amido-N-donor', 'postsynaptic ...
#  of length 560
# {'plasma membrane fusion involved in cytogamy', 'hydrolase activity@ acting on glycosyl bonds', 'oxidoreductase activity@ acting on paired donors@ with incorporation or reduction of molecular oxygen@ reduced ascorbate as one donor@ and incorporation of one atom of oxygen', 'DNA-directed RNA polymerase activity', '3@4-dihydroxybenzoate metabolic process', 'xenobiotic transporter activity', 'phosphotransferase activity@ carboxyl group as acceptor', 'secretion by the type IV secretion system', 'channel activity', 'vitamin transport', 'beta-1@4-mannosylglycoprotein 4-beta-N-acetylglucosaminyltransferase activity', 'pyrimidine nucleotide-sugar transmembrane transport', 'nuclear import signal receptor activity', 'cilium movement involved in cell motility', 'isopentenyl diphosphate biosynthetic process@ mevalonate pathway', 'sodium ion export from cell', 'binding@ bridging', 'single-species biofilm formation', 'potassium:chloride symporter activity', 'hydrolase activity@ acting on carbon-nitrogen (but not peptide) bonds@ in linear amidines', 'glucan 1@4-alpha-glucosidase activity', 'phosphotransferase activity@ alcohol group as acceptor', 'manganese ion transmembrane transporter activity', 'calcium ion import across plasma membrane', 'oxidoreductase activity@ acting on the CH-NH2 group of donors@ NAD or NADP as acceptor', 'exon-exon junction complex', 'mitochondrial electron transport@ ubiquinol to cytochrome c', 'DNA-directed RNA polymerase II@ core complex', 'nucleotide transport', 'mechanically-gated ion channel activity', 'hydrolase activity@ hydrolyzing O-glycosyl compounds', 'pyruvate@ phosphate dikinase activity', 'membrane insertase activity', 'ribonucleoprotein complex', 'transferase activity@ transferring amino-acyl groups', 'hydrolase activity@ acting on acid anhydrides@ in phosphorus-containing anhydrides', 'GDP-mannose 4@6-dehydratase activity', 'proton-transporting ATP synthase complex@ catalytic core F(1)', 'xenobiotic transport', 'oxidoreductase activity@ acting on other nitrogenous compounds as donors@ with NAD or NADP as acceptor', 'hydroxymethyl-@ formyl- and related transferase activity', 'cob(I)yrinic acid a@c-diamide adenosyltransferase activity', 'U4/U6 x U5 tri-snRNP complex', 'proton-transporting ATP synthase complex@ coupling factor F(o)', 'cytoskeleton-dependent cytokinesis', 'RNA polymerase II regulatory region sequence-specific DNA binding', 'anchored component of plasma membrane', 'lysosome localization', 'posttranslational protein targeting to membrane@ translocation', 'mitochondrial proton-transporting ATP synthase complex', 'inositol phosphoceramide synthase regulator activity', 'intramolecular oxidoreductase activity@ interconverting aldoses and ketoses', 'negative regulation of translational elongation', 'transferase activity@ transferring phosphorus-containing groups', 'RNA polymerase I CORE element sequence-specific DNA binding', 'oxidoreductase activity@ acting on paired donors@ with incorporation or reduction of molecular oxygen@ with 2-oxoglutarate as one donor@ and the other dehydrogenated', 'protein unfolding', 'RNA polymerase complex', 'isopentenyl diphosphate biosynthetic process@ methylerythritol 4-phosphate pathway', 'phosphotransferase activity@ for other substituted phosphate groups', 'oxidoreductase activity@ acting on the CH-CH group of donors@ NAD or
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# triangular jaccard similarity of descriptions
jaccard_similarities = np.zeros((len(data), len(data)))
for i, (file1, df1) in enumerate(data.items()):
    for j, (file2, df2) in enumerate(data.items()):
        if i > j:
            continue
        descriptions1 = set(df1["description"])
        descriptions2 = set(df2["description"])
        jaccard_similarities[i, j] = len(descriptions1.intersection(descriptions2)) / len(descriptions1.union(descriptions2))

biomes_of_data = {"ERP016854": "root:Environmental:Aquatic:Freshwater:Lake",
                   "ERP017459": "root:Mixed",
                   "ERP021895": "root:Host-associated:Plants",
                   "ERP110263": "root:Host-associated:Human:Digestive system",
                   "SRP114822": "root:Environmental:Aquatic:Marine"}
biomes_of_data = {k: v.split(":")[-1] for k, v in biomes_of_data.items()}

# plot heatmap
xticks = [file.split("_")[0] for file in data.keys()]
xticks = [x + " (" + biomes_of_data[x] + ")" for x in xticks]
sns.heatmap(jaccard_similarities, xticklabels=xticks, yticklabels=xticks, cmap="YlGnBu", annot=True)
plt.title("Jaccard similarity of descriptions for GO terms in different studies")
plt.show()

# %% [markdown]
# <font color="green">We see that studies of different biomes analysed with the same pipeline give drastically different features (functions found).</font>
#
# ---

# %% [markdown]
# ### Feature space overlap between v4.1-GO annotations summary of 5 difference studies of same biome

# %%
import os
import pandas as pd

# get dataframe for each tsv file in "data/largest_5_studies_GO_v4.1_summary" directory
data = {}
for file in os.listdir("data/human_gut_largest_5_studies_GO_v4.1_summary"):
    if file.endswith(".tsv"):
        data[file] = pd.read_table("data/human_gut_largest_5_studies_GO_v4.1_summary/" + file, usecols=["description"])

# jaccard Similarity heatmap of description of different studies
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# triangular jaccard similarity of descriptions
jaccard_similarities = np.zeros((len(data), len(data)))
for i, (file1, df1) in enumerate(data.items()):
    for j, (file2, df2) in enumerate(data.items()):
        if i > j:
            continue
        descriptions1 = set(df1["description"])
        descriptions2 = set(df2["description"])
        jaccard_similarities[i, j] = len(descriptions1.intersection(descriptions2)) / len(descriptions1.union(descriptions2))

print([key for key in data.keys()])
biomes = {"ERP108956": "root:Host-associated:Human:Digestive system",
         "ERP108957": "root:Host-associated:Human:Digestive system:Large intestine:Fecal",
         "ERP110263": "root:Host-associated:Human:Digestive system",
         "ERP117839": "root:Host-associated:Human:Digestive system:Large intestine:Fecal",
         "SRP096283": "root:Host-associated:Human:Digestive system:Large intestine:Fecal"
         }

biomes = {k: v.split(":")[-1] for k, v in biomes.items()}

# plot heatmap
xticks = [file.split("_")[0] for file in data.keys()]
xticks = [x + " (" + biomes[x] + ")" for x in xticks]
sns.heatmap(jaccard_similarities, xticklabels=xticks, yticklabels=xticks, cmap="YlGnBu", annot=True)
plt.title("Jaccard similarity of descriptions for GO terms in human gut studies")
plt.show()
# Out:
# ['ERP108956_GO_abundances_v4.1.tsv', 'ERP108957_GO_abundances_v4.1.tsv', 'ERP110263_GO_abundances_v4.1.tsv', 'ERP117839_GO_abundances_v4.1.tsv', 'SRP096283_GO_abundances_v4.1.tsv']

# %% [markdown]
# <font color="green">We see that even if the biomes are the same and analysis is done with the same pipeline, the features (functions found) can be different.</font>
#
# ---

# %% [markdown]
# ### Feature space overlap between v4.1-taxonomic SSU summary of 5 difference studies of same biome

# %%
import os
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# get dataframe for each tsv file in "data/largest_5_studies_GO_v4.1_summary" directory
data = {}
for file in os.listdir("data/human_gut_largest_5_studies_taxonomic_SSU_v4.1_summary"):
    if file.endswith(".tsv"):
        data[file] = pd.read_table("data/human_gut_largest_5_studies_taxonomic_SSU_v4.1_summary/" + file, usecols=["#SampleID"])

# jaccard Similarity heatmap of description of different studies
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(1, 2, figsize=(25, 10))

# triangular jaccard similarity of descriptions
jaccard_similarities = np.zeros((len(data), len(data)))
for i, (file1, df1) in enumerate(data.items()):
    for j, (file2, df2) in enumerate(data.items()):
        if i > j:
            continue
        descriptions1 = set(df1["#SampleID"])
        descriptions2 = set(df2["#SampleID"])
        jaccard_similarities[i, j] = len(descriptions1.intersection(descriptions2)) / len(descriptions1.union(descriptions2))

biomes = {"ERP108956": "root:Host-associated:Human:Digestive system",
         "ERP108957": "root:Host-associated:Human:Digestive system:Large intestine:Fecal",
         "ERP110263": "root:Host-associated:Human:Digestive system",
         "ERP117839": "root:Host-associated:Human:Digestive system:Large intestine:Fecal",
         "SRP096283": "root:Host-associated:Human:Digestive system:Large intestine:Fecal"
         }

biomes = {k: v.split(":")[-1] for k, v in biomes.items()}

# plot heatmap
xticks = [file.split("_")[0] for file in data.keys()]
xticks = [x + " (" + biomes[x] + ")" for x in xticks]
sns.heatmap(jaccard_similarities, xticklabels=xticks, yticklabels=xticks, cmap="YlGnBu", annot=True, ax=axes[0])
axes[0].set_title("Jaccard similarity of sample IDs for taxonomic SSU")

# Only focus on Genus level
# These are the rows where the taxonomic level can be split by ";" and the last element starts with "g__"
for df in data.keys():
    data[df] = data[df][data[df]["#SampleID"].apply(lambda x: x.split(";")[-1].startswith("g__"))]
# triangular jaccard similarity of descriptions
jaccard_similarities = np.zeros((len(data), len(data)))
for i, (file1, df1) in enumerate(data.items()):
    for j, (file2, df2) in enumerate(data.items()):
        if i > j:
            continue
        descriptions1 = set(df1["#SampleID"])
        descriptions2 = set(df2["#SampleID"])
        jaccard_similarities[i, j] = len(descriptions1.intersection(descriptions2)) / len(descriptions1.union(descriptions2))

# plot heatmap
xticks = [file.split("_")[0] for file in data.keys()]
xticks = [x + " (" + biomes[x] + ")" for x in xticks]
sns.heatmap(jaccard_similarities, xticklabels=xticks, yticklabels=xticks, cmap="YlGnBu", annot=True, ax=axes[1])
axes[1].set_title("Jaccard similarity of Genus level taxonomic SSU")
plt.show()

# %% [markdown]
# <font color="green">We see that even if the biomes are the same and analysis is done with the same pipeline, the features (taxonomic levels found or genera found) can be different.</font>
#
# ---
