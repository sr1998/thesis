# %%
import sys
sys.path.append("../")

import torch
from torch import Tensor, nn, no_grad, zeros_like
from torch.utils.data import DataLoader, TensorDataset
from torch.optim import SGD, Optimizer

from src.models.maml import Model, Reptile

def main():
    # Set device.
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # Create a synthetic dataset.
    # We'll generate a binary classification problem in 2D.
    N = 1000
    X = torch.randn(N, 2)
    y = (X.sum(dim=1) > 0).long()  # Label is 1 if sum > 0, else 0.
    
    dataset = TensorDataset(X, y)
    # Use a small batch size so that each batch is treated as a "task".
    dataloader = DataLoader(dataset, batch_size=16, shuffle=True)

    # Define a simple model: 2 input features, one hidden layer with 10 units, 2 outputs.
    model = Model(nodes_per_layer=[2, 10, 2],
                  activations_per_layer=[nn.ReLU(), nn.Identity()]).to(device)

    # Define the loss function.
    loss_fn = nn.CrossEntropyLoss()

    # Outer (meta) optimizer: using SGD.
    meta_lr = 1.0  # Outer learning rate.
    meta_optimizer = SGD(model.parameters(), lr=meta_lr)

    # Inner-loop learning rate (α).
    inner_lr = 0.01

    # Number of inner-loop gradient steps per task.
    n_gradient_steps = 5

    # Instantiate the Reptile meta-learner.
    reptile = Reptile(model=model, n_gradient_steps=n_gradient_steps, device=device,
                      loss_function=loss_fn, meta_optimizer=meta_optimizer, inner_lr=inner_lr)

    # Train using Reptile for a few epochs.
    n_epochs = 5
    n_parallel_tasks = 4  # Number of tasks (batches) per meta-update.
    reptile.fit(dataloader, n_epochs=n_epochs, n_parallel_tasks=n_parallel_tasks)

    # (Optional) Evaluate the trained model on the training data.
        # Create a synthetic dataset.
    # We'll generate a binary classification problem in 2D.
    N = 1000
    X = torch.randn(N, 2)
    y = (X.sum(dim=1) > 0).long()  # Label is 1 if sum > 0, else 0.
    
    dataset = TensorDataset(X, y)
    # Use a small batch size so that each batch is treated as a "task".
    dataloader = DataLoader(dataset, batch_size=16, shuffle=True)

    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for X_batch, y_batch in dataloader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            predictions = outputs.argmax(dim=1)
            correct += (predictions == y_batch).sum().item()
            total += y_batch.size(0)
    print(f"Training accuracy: {correct/total*100:.2f}%")

# %%
main()
# Out:
# 2025-02-04 15:26:15.887 | INFO     | src.models.maml:fit:128 - Meta-update iteration 1/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:15.946 | INFO     | src.models.maml:fit:128 - Meta-update iteration 2/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:15.995 | INFO     | src.models.maml:fit:128 - Meta-update iteration 3/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:16.066 | INFO     | src.models.maml:fit:128 - Meta-update iteration 4/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:16.132 | INFO     | src.models.maml:fit:128 - Meta-update iteration 5/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:16.292 | INFO     | src.models.maml:fit:128 - Meta-update iteration 6/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:16.378 | INFO     | src.models.maml:fit:128 - Meta-update iteration 7/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:16.425 | INFO     | src.models.maml:fit:128 - Meta-update iteration 8/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:16.469 | INFO     | src.models.maml:fit:128 - Meta-update iteration 9/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:16.511 | INFO     | src.models.maml:fit:128 - Meta-update iteration 10/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:16.547 | INFO     | src.models.maml:fit:128 - Meta-update iteration 11/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:16.594 | INFO     | src.models.maml:fit:128 - Meta-update iteration 12/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:16.640 | INFO     | src.models.maml:fit:128 - Meta-update iteration 13/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:16.687 | INFO     | src.models.maml:fit:128 - Meta-update iteration 14/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:16.731 | INFO     | src.models.maml:fit:128 - Meta-update iteration 15/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:16.778 | INFO     | src.models.maml:fit:99 - Epoch 1 complete at iteration 16/80 with 4 parallel tasks and 63 total tasks. Reinitializing DataLoader for next epoch.
# 2025-02-04 15:26:16.829 | INFO     | src.models.maml:evaluate:69 - Evaluation after epoch 1: Accuracy = 83.40%
# 2025-02-04 15:26:16.838 | INFO     | src.models.maml:fit:128 - Meta-update iteration 16/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:16.874 | INFO     | src.models.maml:fit:128 - Meta-update iteration 17/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:16.930 | INFO     | src.models.maml:fit:128 - Meta-update iteration 18/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:16.985 | INFO     | src.models.maml:fit:128 - Meta-update iteration 19/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.038 | INFO     | src.models.maml:fit:128 - Meta-update iteration 20/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.112 | INFO     | src.models.maml:fit:128 - Meta-update iteration 21/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.163 | INFO     | src.models.maml:fit:128 - Meta-update iteration 22/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.206 | INFO     | src.models.maml:fit:128 - Meta-update iteration 23/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.265 | INFO     | src.models.maml:fit:128 - Meta-update iteration 24/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.319 | INFO     | src.models.maml:fit:128 - Meta-update iteration 25/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.381 | INFO     | src.models.maml:fit:128 - Meta-update iteration 26/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.425 | INFO     | src.models.maml:fit:128 - Meta-update iteration 27/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.482 | INFO     | src.models.maml:fit:128 - Meta-update iteration 28/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.526 | INFO     | src.models.maml:fit:128 - Meta-update iteration 29/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.580 | INFO     | src.models.maml:fit:128 - Meta-update iteration 30/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.654 | INFO     | src.models.maml:fit:128 - Meta-update iteration 31/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.682 | INFO     | src.models.maml:fit:99 - Epoch 2 complete at iteration 32/80 with 4 parallel tasks and 63 total tasks. Reinitializing DataLoader for next epoch.
# 2025-02-04 15:26:17.738 | INFO     | src.models.maml:evaluate:69 - Evaluation after epoch 2: Accuracy = 88.50%
# 2025-02-04 15:26:17.762 | INFO     | src.models.maml:fit:128 - Meta-update iteration 32/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.825 | INFO     | src.models.maml:fit:128 - Meta-update iteration 33/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.876 | INFO     | src.models.maml:fit:128 - Meta-update iteration 34/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.932 | INFO     | src.models.maml:fit:128 - Meta-update iteration 35/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:17.971 | INFO     | src.models.maml:fit:128 - Meta-update iteration 36/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.029 | INFO     | src.models.maml:fit:128 - Meta-update iteration 37/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.079 | INFO     | src.models.maml:fit:128 - Meta-update iteration 38/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.151 | INFO     | src.models.maml:fit:128 - Meta-update iteration 39/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.192 | INFO     | src.models.maml:fit:128 - Meta-update iteration 40/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.244 | INFO     | src.models.maml:fit:128 - Meta-update iteration 41/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.291 | INFO     | src.models.maml:fit:128 - Meta-update iteration 42/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.326 | INFO     | src.models.maml:fit:128 - Meta-update iteration 43/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.382 | INFO     | src.models.maml:fit:128 - Meta-update iteration 44/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.425 | INFO     | src.models.maml:fit:128 - Meta-update iteration 45/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.472 | INFO     | src.models.maml:fit:128 - Meta-update iteration 46/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.543 | INFO     | src.models.maml:fit:128 - Meta-update iteration 47/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.556 | INFO     | src.models.maml:fit:99 - Epoch 3 complete at iteration 48/80 with 4 parallel tasks and 63 total tasks. Reinitializing DataLoader for next epoch.
# 2025-02-04 15:26:18.607 | INFO     | src.models.maml:evaluate:69 - Evaluation after epoch 3: Accuracy = 99.80%
# 2025-02-04 15:26:18.646 | INFO     | src.models.maml:fit:128 - Meta-update iteration 48/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.695 | INFO     | src.models.maml:fit:128 - Meta-update iteration 49/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.743 | INFO     | src.models.maml:fit:128 - Meta-update iteration 50/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.803 | INFO     | src.models.maml:fit:128 - Meta-update iteration 51/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.852 | INFO     | src.models.maml:fit:128 - Meta-update iteration 52/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.885 | INFO     | src.models.maml:fit:128 - Meta-update iteration 53/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.915 | INFO     | src.models.maml:fit:128 - Meta-update iteration 54/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.948 | INFO     | src.models.maml:fit:128 - Meta-update iteration 55/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:18.982 | INFO     | src.models.maml:fit:128 - Meta-update iteration 56/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.025 | INFO     | src.models.maml:fit:128 - Meta-update iteration 57/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.083 | INFO     | src.models.maml:fit:128 - Meta-update iteration 58/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.119 | INFO     | src.models.maml:fit:128 - Meta-update iteration 59/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.161 | INFO     | src.models.maml:fit:128 - Meta-update iteration 60/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.203 | INFO     | src.models.maml:fit:128 - Meta-update iteration 61/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.253 | INFO     | src.models.maml:fit:128 - Meta-update iteration 62/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.294 | INFO     | src.models.maml:fit:128 - Meta-update iteration 63/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.297 | INFO     | src.models.maml:fit:99 - Epoch 4 complete at iteration 64/80 with 4 parallel tasks and 63 total tasks. Reinitializing DataLoader for next epoch.
# 2025-02-04 15:26:19.350 | INFO     | src.models.maml:evaluate:69 - Evaluation after epoch 4: Accuracy = 97.60%
# 2025-02-04 15:26:19.397 | INFO     | src.models.maml:fit:128 - Meta-update iteration 64/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.440 | INFO     | src.models.maml:fit:128 - Meta-update iteration 65/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.492 | INFO     | src.models.maml:fit:128 - Meta-update iteration 66/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.540 | INFO     | src.models.maml:fit:128 - Meta-update iteration 67/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.599 | INFO     | src.models.maml:fit:128 - Meta-update iteration 68/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.654 | INFO     | src.models.maml:fit:128 - Meta-update iteration 69/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.715 | INFO     | src.models.maml:fit:128 - Meta-update iteration 70/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.758 | INFO     | src.models.maml:fit:128 - Meta-update iteration 71/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.808 | INFO     | src.models.maml:fit:128 - Meta-update iteration 72/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.850 | INFO     | src.models.maml:fit:128 - Meta-update iteration 73/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.898 | INFO     | src.models.maml:fit:128 - Meta-update iteration 74/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.936 | INFO     | src.models.maml:fit:128 - Meta-update iteration 75/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:19.971 | INFO     | src.models.maml:fit:128 - Meta-update iteration 76/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:20.024 | INFO     | src.models.maml:fit:128 - Meta-update iteration 77/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:20.069 | INFO     | src.models.maml:fit:128 - Meta-update iteration 78/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:20.098 | INFO     | src.models.maml:fit:99 - Epoch 5 complete at iteration 79/80 with 4 parallel tasks and 63 total tasks. Reinitializing DataLoader for next epoch.
# 2025-02-04 15:26:20.151 | INFO     | src.models.maml:evaluate:69 - Evaluation after epoch 5: Accuracy = 98.80%
# 2025-02-04 15:26:20.167 | INFO     | src.models.maml:fit:128 - Meta-update iteration 79/80 complete: processed 4 parallel tasks.
# 2025-02-04 15:26:20.216 | INFO     | src.models.maml:fit:128 - Meta-update iteration 80/80 complete: processed 4 parallel tasks.
# Training accuracy: 97.30%
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
