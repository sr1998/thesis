# %%
import pandas as pd

ontology = pd.read_pickle("data/ontology.pkl")
display(ontology)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\shaya\Documents\TU_projects\master_thesis\.thesis_venv\Lib\site-packages\pandas\io\pickle.py:202, in read_pickle(filepath_or_buffer, compression, storage_options)
#     201         warnings.simplefilter("ignore", Warning)
# --> 202         return pickle.load(handles.handle)
#     203 except excs_to_catch:
#     204     # e.g.
#     205     #  "No module named 'pandas.core.sparse.series'"
#     206     #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
#
# ModuleNotFoundError: No module named 'livingTree'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 ontology = pd.read_pickle("data/ontology.pkl")
#       4 display(ontology)
#
# ...
