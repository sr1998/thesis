# %%
import wandb
import pandas as pd
import matplotlib.pyplot as plt

# Initialize wandb API
api = wandb.Api()

# User inputs
project_name = "thesis_baselines"  # Replace with your wandb project name
entity_name = "shayan000"    # Replace with your wandb entity
metric_list = ["test/accuracy", "test/f1_macro", "test/roc_auc"]  # List of metrics to plot

# Fetch runs
runs = api.runs(f"{entity_name}/{project_name}")
runs = [run for run in runs if run.name in ["d_['MGYS00005285']   s_GO-slim_abundances", "d_['MGYS00003619']   s_GO-slim_abundances", "d_['MGYS00003677']   s_GO-slim_abundances"]]

# Collect metrics from the summary table for each run
data = []
for run in runs:
    if "Test Metrics Summary table" in run.summary:
        table = run.summary["Test Metrics Summary table"]  # Get the wandb.Table object
        print(table)
        print(type(table))
        df = table.to_dataframe()  # Convert the table to a pandas DataFrame
        run_metrics = {"Run": run.name}  # Initialize dictionary for current run
        for metric in metric_list:
            if metric in df['Metric'].values:
                value = df.loc[df['Metric'] == metric, 'Mean'].values[0]  # Extract 'Mean' value
                run_metrics[metric] = value
        data.append(run_metrics)

# Create a DataFrame from collected data
df_metrics = pd.DataFrame(data)

# Plot the data
df_metrics.set_index('Run', inplace=True)
df_metrics.plot(kind='bar', figsize=(12, 6))
plt.title("Metrics Comparison Across Runs")
plt.ylabel("Metric Values")
plt.xlabel("Runs")
plt.xticks(rotation=45)
plt.legend(title="Metrics")
plt.tight_layout()
plt.show()
# Out:
# {'_latest_artifact_path': 'wandb-client-artifact://10828xktzo8gu74fslfqlbuzq2duvrik70yka4raopfq9owuxf5ehcl5uyxjbrck4m43sw1n7nkb06tnc3s53wsx1hf1bliu92igyiynldj9nm9slzbz1o6lodlian5m:latest/Test Metrics Summary table.table.json', '_type': 'table-file', 'artifact_path': 'wandb-client-artifact://v7z01vp5l3jl3bvqxrwztsywavwkkon1b0z2b6968suw4ed5nwup02iqwnmmlrp5az3sul7r7tdgx1i5xy19zpj5jminudqmxu2sh4oyhhlzeunwxeh36stlkedojcue/Test Metrics Summary table.table.json', 'ncols': 3, 'nrows': 20, 'path': 'media/table/Test Metrics Summary table_5_e1a0a069afc0f0167924.table.json', 'sha256': 'e1a0a069afc0f0167924195ce72c527700aefcf104c4a5aea1f279c0f55b1945', 'size': 1392}
# <class 'wandb.old.summary.SummarySubDict'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 24
#      22 print(table)
#      23 print(type(table))
# ---> 24 df = table.to_dataframe()  # Convert the table to a pandas DataFrame
#      25 run_metrics = {"Run": run.name}  # Initialize dictionary for current run
#      26 for metric in metric_list:
#
# File c:\Users\shaya\Documents\TU_projects\master_thesis\.thesis_venv\Lib\site-packages\wandb\old\summary.py:56, in SummarySubDict.__getattr__(self, k)
#      54     return object.__getattribute__(self, k)
#      55 else:
# ---> 56     return self[k]
#
# File c:\Users\shaya\Documents\TU_projects\master_thesis\.thesis_venv\Lib\site-packages\wandb\old\summary.py:110, in SummarySubDict.__getitem__(self, k)
#     107     k = k.strip()
#     109 self.get(k)  # load the value into _dict if it should be there
# --> 110 res = self._dict[k]
#     112 return res
#
# KeyError: 'to_dataframe'

# %%
import wandb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def fetch_and_plot_metrics(
    entity,
    project,
    metrics_to_plot,
    run_names=None,
    n_recent_runs=5,
    figsize=(12, 6),
    title="Metrics Comparison Across Runs",
    table_name="Test Metrics Summary table"
):
    """
    Fetch metrics from W&B table and create a bar plot comparison.
    
    Parameters:
    -----------
    entity : str
        W&B entity name (username or team name)
    project : str
        W&B project name
    metrics_to_plot : list
        List of metric names to include in the plot
    run_names : list, optional
        List of specific run names to include. If None, uses n_recent_runs
    n_recent_runs : int, optional
        Number of most recent runs to include if run_names is None
    figsize : tuple, optional
        Figure size (width, height)
    title : str, optional
        Plot title
    table_name : str, optional
        Name of the W&B table containing the metrics
    
    Returns:
    --------
    fig : matplotlib.figure.Figure
        The generated figure
    """
    # Initialize W&B API
    api = wandb.Api()
    
    # Get runs
    runs = api.runs(f"{entity}/{project}")
    
    if run_names:
        runs = [run for run in runs if run.name in run_names]
    else:
        runs = runs[:n_recent_runs]
    
    # Collect metrics from tables
    data = []
    for run in runs:
        try:
            # Access the table from summary
            print(run.summary._json_dict)
            table = run.summary._json_dict[table_name]
            
            # Extract data and column names
            # table_data = table['data']
            # columns = table['columns']
            
            print(table)
            # Convert to DataFrame
            df = table.to_dataframe()
            
            # Get mean values from the table
            metrics_dict = {metric: df[df['Metric'] == metric]['Mean'].iloc[0] 
                          for metric in metrics_to_plot if metric in df['Metric'].values}
            metrics_dict['run_name'] = run.name
            data.append(metrics_dict)
            
        except Exception as e:
            print(f"Warning: Could not process table for run {run.name}. Error: {str(e)}")
            continue
    
    if not data:
        raise ValueError("No valid data could be collected from any runs")
    
    # Convert to DataFrame
    df_plot = pd.DataFrame(data)
    
    # Prepare data for plotting
    plot_data = df_plot.melt(
        id_vars=['run_name'],
        value_vars=metrics_to_plot,
        var_name='Metric',
        value_name='Value'
    )
    
    # Create plot
    plt.figure(figsize=figsize)
    
    # Create grouped bar plot
    sns.barplot(
        data=plot_data,
        x='run_name',
        y='Value',
        hue='Metric',
        palette='husl'
    )
    
    # Customize plot
    plt.title(title, pad=20)
    plt.xticks(rotation=45, ha='right')
    plt.xlabel('Run Name')
    plt.ylabel('Value')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    
    return plt.gcf()

# Configuration
ENTITY = "shayan000"
PROJECT = "thesis_baselines"

# Metrics to compare
METRICS = [
    "test/accuracy",
    "test/f1_macro",
    "test/precision_macro"
]

run_names = ["d_['MGYS00005285']   s_GO-slim_abundances", "d_['MGYS00003619']   s_GO-slim_abundances", "d_['MGYS00003677']   s_GO-slim_abundances"]

fig = fetch_and_plot_metrics(
    entity=ENTITY,
    project=PROJECT,
    metrics_to_plot=METRICS,
    n_recent_runs=3,
    run_names=run_names
)

plt.show()
# Out:
# {'Data description': {'_latest_artifact_path': 'wandb-client-artifact://2191imov5u6du0m5axe6qg0e7ue4ynytcwvv50k78wnn8kydggzlfjen7jww80v9lbekvy9vfqw8ysntpjgh3eamkz9a69vvp32g5hhjzdcumfco6y5p9dm5potwpmi6:latest/Data description.table.json', '_type': 'table-file', 'artifact_path': 'wandb-client-artifact://r05vjicj9ohws9q7t3lavz5ea03bjprra9gfwoz4b5hbo3gdt3meac30183ivojup8ma2vfud6kfexigxehloyd9hcaz81xytgb6v5pk1yc00xlo7d424td5c03xg04f/Data description.table.json', 'ncols': 9, 'nrows': 116, 'path': 'media/table/Data description_0_5cf58a8e15e59f1e1c74.table.json', 'sha256': '5cf58a8e15e59f1e1c7458ef47523394b96b9c06135e7cc5abf9534a8c4131ae', 'size': 11369}, 'Outer fold.test/accuracy': 0.6153846153846154, 'Outer fold.test/average_precision(_macro)': 0.625987525987526, 'Outer fold.test/average_precision_micro': 0.625987525987526, 'Outer fold.test/average_precision_weighted': 0.625987525987526, 'Outer fold.test/balanced_accuracy': 0.6013513513513513, 'Outer fold.test/f1(_binary)': 0.6753246753246753, 'Outer fold.test/f1_macro': 0.6753246753246753, 'Outer fold.test/f1_micro': 0.6753246753246753, 'Outer fold.test/f1_weighted': 0.6753246753246753, 'Outer fold.test/precision(_binary)': 0.65, 'Outer fold.test/precision_macro': 0.65, 'Outer fold.test/precision_micro': 0.65, 'Outer fold.test/precision_weighted': 0.65, 'Outer fold.test/recall(_binary)': 0.7027027027027027, 'Outer fold.test/recall_macro': 0.7027027027027027, 'Outer fold.test/recall_micro': 0.7027027027027027, 'Outer fold.test/recall_weighted': 0.7027027027027027, 'Outer fold.test/roc_auc(_macro)': 0.6013513513513513, 'Outer fold.test/roc_auc_micro': 0.6013513513513513, 'Outer fold.test/roc_auc_weighted': 0.6013513513513513, 'Outer fold.train/accuracy': 1, 'Outer fold.train/average_precision(_macro)': 1, 'Outer fold.train/average_precision_micro': 1, 'Outer fold.train/average_precision_weighted': 1, 'Outer fold.train/balanced_accuracy': 1, 'Outer fold.train/f1(_binary)': 1, 'Outer fold.train/f1_macro': 1, 'Outer fold.train/f1_micro': 1, 'Outer fold.train/f1_weighted': 1, 'Outer fold.train/precision(_binary)': 1, 'Outer fold.train/precision_macro': 1, 'Outer fold.train/precision_micro': 1, 'Outer fold.train/precision_weighted': 1, 'Outer fold.train/recall(_binary)': 1, 'Outer fold.train/recall_macro': 1, 'Outer fold.train/recall_micro': 1, 'Outer fold.train/recall_weighted': 1, 'Outer fold.train/roc_auc(_macro)': 1, 'Outer fold.train/roc_auc_micro': 1, 'Outer fold.train/roc_auc_weighted': 1, 'Test Metrics Summary table': {'_latest_artifact_path': 'wandb-client-artifact://10828xktzo8gu74fslfqlbuzq2duvrik70yka4raopfq9owuxf5ehcl5uyxjbrck4m43sw1n7nkb06tnc3s53wsx1hf1bliu92igyiynldj9nm9slzbz1o6lodlian5m:latest/Test Metrics Summary table.table.json', '_type': 'table-file', 'artifact_path': 'wandb-client-artifact://v7z01vp5l3jl3bvqxrwztsywavwkkon1b0z2b6968suw4ed5nwup02iqwnmmlrp5az3sul7r7tdgx1i5xy19zpj5jminudqmxu2sh4oyhhlzeunwxeh36stlkedojcue/Test Metrics Summary table.table.json', 'ncols': 3, 'nrows': 20, 'path': 'media/table/Test Metrics Summary table_5_e1a0a069afc0f0167924.table.json', 'sha256': 'e1a0a069afc0f0167924195ce72c527700aefcf104c4a5aea1f279c0f55b1945', 'size': 1392}, 'Train Metrics Summary table': {'_latest_artifact_path': 'wandb-client-artifact://oqcxk26iyv1nzd6pttzp955gpvbok3oogdp0xo4xblexcbwis3gb9s5664szi7h59uvrwl0qrr77lh4q9vmeecef98ourpxwl7ws4bibi6rfcz8aphuat2875x4l0rmo:latest/Train Metrics Summary table.table.json', '_type': 'table-file', 'artifact_path': 'wandb-client-artifact://w0zp8gdr4dso39poxbhz74qifo52ck0030z770ve7wwaj0yeuccohygg7vcziunrmeomf0q1033r0nkifu3v5e0x5lus04986yks81eslgolqh5lt9xofm1d1ea2xjem/Train Metrics Summary table.table.json', 'ncols': 3, 'nrows': 20, 'path': 'media/table/Train Metrics Summary table_4_4b0fad9b9d691a6c2002.table.json', 'sha256': '4b0fad9b9d691a6c20028f3fbba489e06edf69991d606fa1ed4a5ac257db1706', 'size': 789}, '_runtime': 3521.232214668, '_step': 5, '_timestamp': 1736252822.7101018, '_wandb.runtime': 3521, 'labels': {'_latest_artifact_path' ...
# {'_latest_artifact_path': 'wandb-client-artifact://10828xktzo8gu74fslfqlbuzq2duvrik70yka4raopfq9owuxf5ehcl5uyxjbrck4m43sw1n7nkb06tnc3s53wsx1hf1bliu92igyiynldj9nm9slzbz1o6lodlian5m:latest/Test Metrics Summary table.table.json', '_type': 'table-file', 'artifact_path': 'wandb-client-artifact://v7z01vp5l3jl3bvqxrwztsywavwkkon1b0z2b6968suw4ed5nwup02iqwnmmlrp5az3sul7r7tdgx1i5xy19zpj5jminudqmxu2sh4oyhhlzeunwxeh36stlkedojcue/Test Metrics Summary table.table.json', 'ncols': 3, 'nrows': 20, 'path': 'media/table/Test Metrics Summary table_5_e1a0a069afc0f0167924.table.json', 'sha256': 'e1a0a069afc0f0167924195ce72c527700aefcf104c4a5aea1f279c0f55b1945', 'size': 1392}
# Warning: Could not process table for run d_['MGYS00005285']   s_GO-slim_abundances. Error: 'dict' object has no attribute 'to_dataframe'
# {'Data description': {'_latest_artifact_path': 'wandb-client-artifact://7h3wwgpl79yevnipf7n6upk5erc4ajr72zreeft0lsrkj9a1tnveyfsay9ap8a2rh71szbbllhhsz4nbkywzomyp3byxgd9iae55e5wv8j2a53i2i02t9qgn1t33tl4r:latest/Data description.table.json', '_type': 'table-file', 'artifact_path': 'wandb-client-artifact://72z191vxmymiqw9d02ndbh1sm74q9hy97cgphv5sundq3i8pu3rpbq6gv0o4u1yw2khkpv54uk32mpcg9inn6tyigd0cy9xe7zwhuk06la9p1s00s9433dzmgyi5jzj9/Data description.table.json', 'ncols': 9, 'nrows': 116, 'path': 'media/table/Data description_0_3845fee870e82ed6ba2f.table.json', 'sha256': '3845fee870e82ed6ba2ffb9be1b5f74dfe8833037617a9512c6fc7ce47e1cf32', 'size': 10990}, 'Outer fold.test/accuracy': 0.7986577181208053, 'Outer fold.test/average_precision(_macro)': 0.1901366251198466, 'Outer fold.test/average_precision_micro': 0.1901366251198466, 'Outer fold.test/average_precision_weighted': 0.1901366251198466, 'Outer fold.test/balanced_accuracy': 0.5054604486422668, 'Outer fold.test/f1(_binary)': 0.0625, 'Outer fold.test/f1_macro': 0.0625, 'Outer fold.test/f1_micro': 0.0625, 'Outer fold.test/f1_weighted': 0.0625, 'Outer fold.test/precision(_binary)': 0.25, 'Outer fold.test/precision_macro': 0.25, 'Outer fold.test/precision_micro': 0.25, 'Outer fold.test/precision_weighted': 0.25, 'Outer fold.test/recall(_binary)': 0.03571428571428571, 'Outer fold.test/recall_macro': 0.03571428571428571, 'Outer fold.test/recall_micro': 0.03571428571428571, 'Outer fold.test/recall_weighted': 0.03571428571428571, 'Outer fold.test/roc_auc(_macro)': 0.5054604486422669, 'Outer fold.test/roc_auc_micro': 0.5054604486422669, 'Outer fold.test/roc_auc_weighted': 0.5054604486422669, 'Outer fold.train/accuracy': 1, 'Outer fold.train/average_precision(_macro)': 1, 'Outer fold.train/average_precision_micro': 1, 'Outer fold.train/average_precision_weighted': 1, 'Outer fold.train/balanced_accuracy': 1, 'Outer fold.train/f1(_binary)': 1, 'Outer fold.train/f1_macro': 1, 'Outer fold.train/f1_micro': 1, 'Outer fold.train/f1_weighted': 1, 'Outer fold.train/precision(_binary)': 1, 'Outer fold.train/precision_macro': 1, 'Outer fold.train/precision_micro': 1, 'Outer fold.train/precision_weighted': 1, 'Outer fold.train/recall(_binary)': 1, 'Outer fold.train/recall_macro': 1, 'Outer fold.train/recall_micro': 1, 'Outer fold.train/recall_weighted': 1, 'Outer fold.train/roc_auc(_macro)': 1, 'Outer fold.train/roc_auc_micro': 1, 'Outer fold.train/roc_auc_weighted': 1, 'Test Metrics Summary table': {'_latest_artifact_path': 'wandb-client-artifact://4eecosvdvxtzqn6q3w2of78yq1ovhrvge5voiob13nn1zimjjoh28z60ys6q2ci7a98vh9r3qfhn0ag7rw4tc5qucvcgvak7v155414jwbtsr8c6d5b0d0x9ap016n2t:latest/Test Metrics Summary table.table.json', '_type': 'table-file', 'artifact_path': 'wandb-client-artifact://pft6wituh3c0j655lxbronoxezwtwrr14v51jp6veku3dsd3hy1sdfexr5guewg8pcnbcnubj9znvwdw4kru7f4x6esb0exmqsn76dh9059gjxrmkat8p59pkfo6k330/Test Metrics Summary table.table.json', 'ncols': 3, 'nrows': 20, 'path': 'media/table/Test Metrics Summary table_5_5e65776e213e83bf1d1d.table.json', 'sha256': '5e65776e213e83bf1d1daa3cbd4ee21464514b45cfcb3350476aebead3252297', 'size': 1394}, 'Train Metrics Summary table': {'_latest_artifact_path': 'wandb-client-artifact://nouhrgx9k6ysrfakcc78593qam7vzd7fudyvwwregrg83j08frffk2ppzf1jc3pb7n54hstb9uuz9hum2bez21db9sapug8q3apa2fwltd1g72tha5f98lryvypl8p4u:latest/Train Metrics Summary table.table.json', '_type': 'table-file', 'artifact_path': 'wandb-client-artifact://8bvuh8u22t0kei1e5aaqejjqowaxdj0oux14ch81h6fdacru6zgdywi9emd4x5dxopsi8gb60yvhm65l6kp0vzo33q6vrgws9vopgso8jjv26ytg19grcdtxsh80i9a0/Train Metrics Summary table.table.json', 'ncols': 3, 'nrows': 20, 'path': 'media/table/Train Metrics Summary table_4_4b0fad9b9d691a6c2002.table.json', 'sha256': '4b0fad9b9d691a6c20028f3fbba489e06edf69991d606fa1ed4a5ac257db1706', 'size': 789}, '_runtime': 4785.42482091, '_step': 5, '_timestamp': 1736254941.6041596, '_wandb.runtime': 4785, 'labels': {'_latest_artifact_path': 'wandb-client-artifact://5por9i28d65emgp ...
# {'_latest_artifact_path': 'wandb-client-artifact://4eecosvdvxtzqn6q3w2of78yq1ovhrvge5voiob13nn1zimjjoh28z60ys6q2ci7a98vh9r3qfhn0ag7rw4tc5qucvcgvak7v155414jwbtsr8c6d5b0d0x9ap016n2t:latest/Test Metrics Summary table.table.json', '_type': 'table-file', 'artifact_path': 'wandb-client-artifact://pft6wituh3c0j655lxbronoxezwtwrr14v51jp6veku3dsd3hy1sdfexr5guewg8pcnbcnubj9znvwdw4kru7f4x6esb0exmqsn76dh9059gjxrmkat8p59pkfo6k330/Test Metrics Summary table.table.json', 'ncols': 3, 'nrows': 20, 'path': 'media/table/Test Metrics Summary table_5_5e65776e213e83bf1d1d.table.json', 'sha256': '5e65776e213e83bf1d1daa3cbd4ee21464514b45cfcb3350476aebead3252297', 'size': 1394}
# Warning: Could not process table for run d_['MGYS00003619']   s_GO-slim_abundances. Error: 'dict' object has no attribute 'to_dataframe'
# {'Data description': {'_latest_artifact_path': 'wandb-client-artifact://klwxntm34ptj6acx59ixqtpguvs5tyfgbdpa3j4by8jhqvg6zuhzy1xfh2vptvjta2lq9if49wto0wh46zhob5ls3qp7b2yvshhcnhso8fpm7w2wkgzxar0ykjuv1kka:latest/Data description.table.json', '_type': 'table-file', 'artifact_path': 'wandb-client-artifact://9wwaj4ggazva888hpepcmir5lt444hua8robpjfs35xr0se1usg01vs2n2zt2c8jj5ppotpqux3w49z9pv8y37kwwldfnznexiw13jmefm6f27d6nn7re74rlj466mwh/Data description.table.json', 'ncols': 9, 'nrows': 116, 'path': 'media/table/Data description_0_26c481e75400bed99f25.table.json', 'sha256': '26c481e75400bed99f2526930b614e43ae962d2cd46e11420c99abf774104335', 'size': 9690}, 'Outer fold.test/accuracy': 0.7553956834532374, 'Outer fold.test/average_precision(_macro)': 0.2302158273381295, 'Outer fold.test/average_precision_micro': 0.2302158273381295, 'Outer fold.test/average_precision_weighted': 0.2302158273381295, 'Outer fold.test/balanced_accuracy': 0.49065420560747663, 'Outer fold.test/f1(_binary)': 0, 'Outer fold.test/f1_macro': 0, 'Outer fold.test/f1_micro': 0, 'Outer fold.test/f1_weighted': 0, 'Outer fold.test/precision(_binary)': 0, 'Outer fold.test/precision_macro': 0, 'Outer fold.test/precision_micro': 0, 'Outer fold.test/precision_weighted': 0, 'Outer fold.test/recall(_binary)': 0, 'Outer fold.test/recall_macro': 0, 'Outer fold.test/recall_micro': 0, 'Outer fold.test/recall_weighted': 0, 'Outer fold.test/roc_auc(_macro)': 0.49065420560747663, 'Outer fold.test/roc_auc_micro': 0.49065420560747663, 'Outer fold.test/roc_auc_weighted': 0.49065420560747663, 'Outer fold.train/accuracy': 1, 'Outer fold.train/average_precision(_macro)': 1, 'Outer fold.train/average_precision_micro': 1, 'Outer fold.train/average_precision_weighted': 1, 'Outer fold.train/balanced_accuracy': 1, 'Outer fold.train/f1(_binary)': 1, 'Outer fold.train/f1_macro': 1, 'Outer fold.train/f1_micro': 1, 'Outer fold.train/f1_weighted': 1, 'Outer fold.train/precision(_binary)': 1, 'Outer fold.train/precision_macro': 1, 'Outer fold.train/precision_micro': 1, 'Outer fold.train/precision_weighted': 1, 'Outer fold.train/recall(_binary)': 1, 'Outer fold.train/recall_macro': 1, 'Outer fold.train/recall_micro': 1, 'Outer fold.train/recall_weighted': 1, 'Outer fold.train/roc_auc(_macro)': 1, 'Outer fold.train/roc_auc_micro': 1, 'Outer fold.train/roc_auc_weighted': 1, 'Test Metrics Summary table': {'_latest_artifact_path': 'wandb-client-artifact://xs692fqngnuq9gszixnij09jf8ywo14bwclz3f2co0on5ekliqfuf9qeyd9s20o3u5qesb9x8n9jv86zt1m8z3xdgimvc2jvk27t0u6dcdf1mkd7yuelhywb6akv8n2q:latest/Test Metrics Summary table.table.json', '_type': 'table-file', 'artifact_path': 'wandb-client-artifact://ejxhz7yuyolezlmp39qr4a0t2unhntikz6bovoh8ukzqn6h3vkouh0u6nqg97hpbp04p0xu66sdf1n1805svfcc41jt0l80mjwf6f8371cx0tizs5q9nbfgnu6b8a878/Test Metrics Summary table.table.json', 'ncols': 3, 'nrows': 20, 'path': 'media/table/Test Metrics Summary table_5_8ba6b03b65d6c961338f.table.json', 'sha256': '8ba6b03b65d6c961338fd74510588a2cabaf18b3feb6a8ec57e9a19a558c8efb', 'size': 1353}, 'Train Metrics Summary table': {'_latest_artifact_path': 'wandb-client-artifact://rjy94iq83117xs92sjy5b54boo8otd96avbzubzx2aux5zqryxlpdz4sgzr9z7muv8p5zgxueo48ooh4t7ieeb227jvzrxvoe7w6v3yqkhigsufqmgyi8qdm6kgidhly:latest/Train Metrics Summary table.table.json', '_type': 'table-file', 'artifact_path': 'wandb-client-artifact://476y8j31yv6pbnz4rgwjta8iz0ilx1rzwyb26gyoh1fpcqw2d04j85jao40tinzbj6bdk3yztymt8mjrentq8ki4ebthe9bzjo6uwvl13xcoupwq8jmgaf2lqovtxyz9/Train Metrics Summary table.table.json', 'ncols': 3, 'nrows': 20, 'path': 'media/table/Train Metrics Summary table_4_e35fd9fff7d4081a62c9.table.json', 'sha256': 'e35fd9fff7d4081a62c946511929bb05c44790f531cc08d6ed69474ccbdf3ad8', 'size': 1422}, '_runtime': 4251.476506926, '_step': 5, '_timestamp': 1736264392.5250287, '_wandb.runtime': 4251, 'labels': {'_latest_artifact_path': 'wandb-client-artifact://ktxc0ngn06e05zroige84b6jzmtcj5gwic8mcew9yk3z9oo10n9mhdv0n0elqbkcchrfevztu71l4xyo7c4abrybfjp1mepd806uyi8xf0rf4cdo7l ...
# {'_latest_artifact_path': 'wandb-client-artifact://xs692fqngnuq9gszixnij09jf8ywo14bwclz3f2co0on5ekliqfuf9qeyd9s20o3u5qesb9x8n9jv86zt1m8z3xdgimvc2jvk27t0u6dcdf1mkd7yuelhywb6akv8n2q:latest/Test Metrics Summary table.table.json', '_type': 'table-file', 'artifact_path': 'wandb-client-artifact://ejxhz7yuyolezlmp39qr4a0t2unhntikz6bovoh8ukzqn6h3vkouh0u6nqg97hpbp04p0xu66sdf1n1805svfcc41jt0l80mjwf6f8371cx0tizs5q9nbfgnu6b8a878/Test Metrics Summary table.table.json', 'ncols': 3, 'nrows': 20, 'path': 'media/table/Test Metrics Summary table_5_8ba6b03b65d6c961338f.table.json', 'sha256': '8ba6b03b65d6c961338fd74510588a2cabaf18b3feb6a8ec57e9a19a558c8efb', 'size': 1353}
# Warning: Could not process table for run d_['MGYS00003677']   s_GO-slim_abundances. Error: 'dict' object has no attribute 'to_dataframe'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 129
#     121 METRICS = [
#     122     "test/accuracy",
#     123     "test/f1_macro",
#     124     "test/precision_macro"
#     125 ]
#     127 run_names = ["d_['MGYS00005285']   s_GO-slim_abundances", "d_['MGYS00003619']   s_GO-slim_abundances", "d_['MGYS00003677']   s_GO-slim_abundances"]
# --> 129 fig = fetch_and_plot_metrics(
#     130     entity=ENTITY,
#     131     project=PROJECT,
#     132     metrics_to_plot=METRICS,
#     133     n_recent_runs=3,
#     134     run_names=run_names
#     135 )
#     137 plt.show()
#
# Cell In[25], line 81, in fetch_and_plot_metrics(entity, project, metrics_to_plot, run_names, n_recent_runs, figsize, title, table_name)
#      78         continue
#      80 if not data:
# ---> 81     raise ValueError("No valid data could be collected from any runs")
#      83 # Convert to DataFrame
#      84 df_plot = pd.DataFrame(data)
#
# ValueError: No valid data could be collected from any runs
